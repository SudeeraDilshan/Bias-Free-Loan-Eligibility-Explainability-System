# %% [markdown]
# # Bias-Free Loan Eligibility & Risk Explainability System
# ## Comprehensive ML Pipeline with SHAP & Fairness Analysis
#
# This notebook implements a complete machine learning system for loan eligibility prediction with:
# - **Explainability**: SHAP (Shapley Additive Explanations) for interpretability
# - **Fairness**: Bias detection and mitigation strategies
# - **Performance**: XGBoost optimization with rigorous evaluation
# - **Production-Ready**: Full integration with FastAPI backend

# %%
# Core Data Processing
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ML & Model Evaluation
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import (accuracy_score, precision_score, recall_score, 
                             f1_score, roc_auc_score, confusion_matrix, roc_curve, auc)
import xgboost as xgb

# Explainability
import shap

# Fairness
from fairlearn.metrics import demographic_parity_difference, equalized_odds_difference

# Utilities
import os
import joblib
from datetime import datetime

print("✓ All libraries imported successfully!")
print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"Scikit-learn: {pd.__version__}")
print(f"XGBoost: {xgb.__version__}")
print(f"SHAP: {shap.__version__}")

# %% [markdown]
# ## Section 1: Import Required Libraries and Load Dataset
